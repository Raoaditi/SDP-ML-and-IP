# %% [markdown]
# # **Aditi Rao EXTC B 118A2088**

# %% [markdown]
# ![d8d97abd-12f4-4d7e-ae44-e636ff2f0987.png](data:image/png;base64,...)

# %%
student_name=["Aditi", "Rao"]
student_roll=[1,2]
z=zip(student_name,student_roll)
students = dict(z)
print(students)
# Out:
# {'Aditi': 1, 'Rao': 2}

# %%
countries=['spain', 'france', 'germany', 'norway']
capitals=['madrid', 'paris', 'berlin', 'oslo']
z=zip(countries, capitals)
europe=dict(z)
print(europe)
# Out:
# {'spain': 'madrid', 'france': 'paris', 'germany': 'berlin', 'norway': 'oslo'}

# %%
student_list=[['Aditi', '88'], ['Ritika', '888'], ['Nitika', '8888']]
for students in student_list:
  for field in students:
    print(field,end=" ")
print()
# Out:
# Aditi 88 Ritika 888 Nitika 8888

# %%
areas=["hallway",11.25,"kitchen",18.0,"living room",20.0,"bedroom",10.75,"bathroom",9.50]
print(areas[1])
print(areas[-1])
d=["balcony",4.5]
areas.append(d)
areas
# Out:
# 11.25
# 9.5
# ['hallway',
#  11.25,
#  'kitchen',
#  18.0,
#  'living room',
#  20.0,
#  'bedroom',
#  10.75,
#  'bathroom',
#  9.5,
#  ['balcony', 4.5]]

# %%
areas=['hallway', 11.25, 'kitchen', 18.0, 'living room', 20.0, 'bedroom', 10.75, 'bathroom', 9.5, ['balcony', 4.5]]
areas.remove('living room')
areas.insert(4,'chill zone')

areas
# Out:
# ['hallway',
#  11.25,
#  'kitchen',
#  18.0,
#  'chill zone',
#  20.0,
#  'bedroom',
#  10.75,
#  'bathroom',
#  9.5,
#  ['balcony', 4.5]]

# %%
areas=['hallway', 11.25, 'kitchen', 18.0, 'chill zone', 20.0, 'bedroom', 10.75, 'bathroom', 9.5, ['balcony', 4.5]]
areas.remove('bedroom')
areas.insert(6,'children bedroom')

# %%
areas.reverse()
areas
# Out:
# [['balcony', 4.5],
#  9.5,
#  'bathroom',
#  10.75,
#  'children bedroom',
#  20.0,
#  'chill zone',
#  18.0,
#  'kitchen',
#  11.25,
#  'hallway']

# %%
a=((1,"Aditi",88),(2,"Rao",88))

alist=list(a)
del alist[0]
alist
# Out:
# [(2, 'Rao', 88)]
