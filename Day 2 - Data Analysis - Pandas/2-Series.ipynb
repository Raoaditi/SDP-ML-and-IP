# %% [markdown]
# # Series

# %% [markdown]
# A Series is very similar to a NumPy array. The difference between two is that a Series can have axis labels, meaning it can be indexed by a label, instead of just a number location. It also doesn't need to hold numeric data, it can hold any arbitrary Python Object.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Creating a Series
#
# We can convert a list,numpy array, or dictionary to a Series.

# %% [markdown]
# ** Using Lists**

# %%
X = [10,20,30]
Y = np.array(['a','b','c'])
type(Y)
# Out:
# numpy.ndarray

# %%
Y[0]
# Out:
# 'a'

# %%
# A = pd.Series(data=X)
A = pd.Series([1,2,3])
type(A)
# Out:
# pandas.core.series.Series

# %%
A
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
B=pd.Series([10,20],['dog','cats'])
print(B)
# Out:
# dog     10
# cats    20
# dtype: int64

# %%
B['a']
# Out:
# 1

# %% [markdown]
# ** Using NumPy Arrays **

# %%
X1 = np.array([10,20,30])
Y1 = ['a', 'b', 'c']

# %%
pd.Series(X1)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int32

# %%
pd.Series(X1, Y1)
# Out:
# a    10
# b    20
# c    30
# dtype: int32

# %% [markdown]
# ** Using Dictionary**

# %%
X3 = {'x':10,'y':20,'z':30}

# %%
pd.Series(X3)
# Out:
# x    10
# y    20
# z    30
# dtype: int64

# %% [markdown]
# ## Using an Index
#
# The key to using a Series is understanding its index. Pandas makes use of these index names or numbers by allowing for fast look ups of information.

# %%
a = pd.Series([1,2,3,4],index = ['USA', 'Germany','USSR', 'Japan'])

# %%
a
# Out:
# USA        1
# Germany    2
# USSR       3
# Japan      4
# dtype: int64

# %%
b = pd.Series([1,2,5,4],index = ['USA', 'Germany','Italy', 'Japan'])

# %%
b
# Out:
# USA        1
# Germany    2
# Italy      5
# Japan      4
# dtype: int64

# %%
a['USA']
# Out:
# 1

# %%
a + b
# Out:
# Germany    4.0
# Italy      NaN
# Japan      8.0
# USA        2.0
# USSR       NaN
# dtype: float64
